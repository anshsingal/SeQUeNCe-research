# %%
import csv
import numpy as np
from matplotlib import pyplot as plt


experimental_counterProp_data_powers = 10**np.array([13.389, 13.692, 14.002, 14.316, 14.765])
experimental_counterProp_data_noise = 10**np.array([4.841, 5.105, 5.384, 5.694, 6.126])

experimental_coProp_data_powers = 10**np.array([13.389, 13.692, 14.002, 14.319, 14.763])
experimental_coProp_data_noise = 10**np.array([4.696, 4.962, 5.243, 5.529, 5.943])

# %%
raman_coProp_file = open('results/ramanCoProp.csv', 'r')

csv_input = zip(*csv.reader(raman_coProp_file))

# for i in csv_input:
#     print(i)

powers = list(map(float, next(csv_input)[1:]))
noise = np.array(list(map(float, next(csv_input)[1:])))

print(noise)

h = 6.62607015 * 10**(-34)
c = 3*10**8
wl = 1310.*10**(-9)
powers = (wl/(h*c))*np.array(powers)
# print(noise)

plt.loglog(powers, 2.2*noise, 'b-x', label='Simulated Co-propagating signal')
plt.loglog(experimental_coProp_data_powers, experimental_coProp_data_noise, 'bo', label='Experimental Co-propagating signal')

raman_counterProp_file = open('results/ramanCounterProp.csv', 'r')

csv_input = zip(*csv.reader(raman_counterProp_file))
powers = list(map(float, next(csv_input)[1:]))
noise = np.array(list(map(float, next(csv_input)[1:])))

print(noise)

h = 6.62607015 * 10**(-34)
c = 3*10**8
wl = 1310.*10**(-9)
powers = (wl/(h*c))*np.array(powers)
# print(noise)

plt.loglog(powers, 2.2*noise, 'r-x', label='Simulated Counter-propagating signal')
plt.loglog(experimental_counterProp_data_powers, experimental_counterProp_data_noise, 'ro', label='Experimental Counter-propagating signal')

plt.ylim((10**4, 10**7))
plt.xlim((10**13, 10**15))
plt.legend()
plt.xlabel("Launch Power (Photons/s)")
plt.ylabel("Raman noise (Counts/s)")
# print(powers)
# print(noise)



# next()

# for i in csv_input:
#     print(i)
# print()
# data = zip(*[map(int, row) for row in csv_input])
# print(data[0])
# Out:
# [  8280.  12030.  17310.  24480.  35830.  52240.  75400. 110790. 158350.
#  231360. 331430. 479140.]
# [ 11860.  17910.  25670.  35890.  55010.  78650. 113600. 160910. 234320.
#  339390. 490160. 710450.]
# Text(0, 0.5, 'Raman noise (Counts/s)')

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

def read_csv_data(file_path):
    raman_coProp_file = open(file_path, 'r')
    csv_input = list(zip(*csv.reader(raman_coProp_file)))
    powers = list(map(int, csv_input[0][1:]))
    visibilities = list(map(float, csv_input[5][1:]))

    powers, visibilities = zip(*sorted(zip(powers, visibilities)))
    return powers, visibilities


file_path = 'results/Final_Set1/final_data_L_CO_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_L_CO_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
visibilities = list(zip(visibilities1, visibilities2))
mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-x', label = "L-Band, FS")


file_path = 'results/Final_Set1/final_data_L_COUNTER_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_L_COUNTER_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
visibilities = list(zip(visibilities1, visibilities2))
mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-o', label = "L-Band, BS")


file_path = 'results/Final_Set1/final_data_O_CO_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_O_CO_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
visibilities = list(zip(visibilities1, visibilities2))
mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-x', label = "O-Band, FS")


file_path = 'results/Final_Set1/final_data_O_COUNTER_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_O_COUNTER_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
visibilities = list(zip(visibilities1, visibilities2))
mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-o', label = "O-Band, BS")

plt.legend()
plt.ylabel("Visibility")
plt.xlabel("Classical Launch Power (dBm)")




# import matplotlib.pyplot as plt
# import numpy as np
# import csv

# def read_csv_data(file_path):
#     raman_coProp_file = open(file_path, 'r')
#     csv_input = list(zip(*csv.reader(raman_coProp_file)))
#     powers = list(map(int, csv_input[0][1:]))
#     visibilities = list(map(float, csv_input[5][1:]))

#     powers, visibilities = zip(*sorted(zip(powers, visibilities)))
#     return powers, visibilities


# file_path = 'results/Final_Set1/final_data_L_CO_4PAM/final_data.csv'
# powers, visibilities1 = read_csv_data(file_path)
# file_path = 'results/Final_Set2/final_data_L_CO_4PAM/final_data.csv'
# powers, visibilities2 = read_csv_data(file_path)
# file_path = 'results/final_data_L_CO_4PAM/final_data.csv'
# powers, visibilities3 = read_csv_data(file_path)
# visibilities = list(zip(visibilities1, visibilities2, visibilities3))
# mean_visibilities = np.mean(visibilities, 1)
# std_visibilities = np.std(visibilities, 1)
# plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-x', label = "L-Band, FS")


# file_path = 'results/Final_Set1/final_data_L_COUNTER_4PAM/final_data.csv'
# powers, visibilities1 = read_csv_data(file_path)
# file_path = 'results/Final_Set2/final_data_L_COUNTER_4PAM/final_data.csv'
# powers, visibilities2 = read_csv_data(file_path)
# file_path = 'results/final_data_L_COUNTER_4PAM/final_data.csv'
# powers, visibilities3 = read_csv_data(file_path)
# visibilities = list(zip(visibilities1, visibilities2, visibilities3))
# mean_visibilities = np.mean(visibilities, 1)
# std_visibilities = np.std(visibilities, 1)
# plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-o', label = "L-Band, BS")


# file_path = 'results/Final_Set1/final_data_O_CO_4PAM/final_data.csv'
# powers, visibilities1 = read_csv_data(file_path)
# file_path = 'results/Final_Set2/final_data_O_CO_4PAM/final_data.csv'
# powers, visibilities2 = read_csv_data(file_path)
# file_path = 'results/final_data_O_CO_4PAM/final_data.csv'
# powers, visibilities3 = read_csv_data(file_path)
# visibilities = list(zip(visibilities1, visibilities2, visibilities3))
# mean_visibilities = np.mean(visibilities, 1)
# std_visibilities = np.std(visibilities, 1)
# plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-x', label = "O-Band, FS")


# file_path = 'results/Final_Set1/final_data_O_COUNTER_4PAM/final_data.csv'
# powers, visibilities1 = read_csv_data(file_path)
# file_path = 'results/Final_Set2/final_data_O_COUNTER_4PAM/final_data.csv'
# powers, visibilities2 = read_csv_data(file_path)
# file_path = 'results/final_data_O_COUNTER_4PAM/final_data.csv'
# powers, visibilities3 = read_csv_data(file_path)
# visibilities = list(zip(visibilities1, visibilities2, visibilities3))
# mean_visibilities = np.mean(visibilities, 1)
# std_visibilities = np.std(visibilities, 1)
# plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-o', label = "O-Band, BS")

# plt.legend()
# Out:
# Text(0.5, 0, 'Classical Launch Power (dBm)')

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

def read_csv_data(file_path):
    raman_coProp_file = open(file_path, 'r')
    csv_input = list(zip(*csv.reader(raman_coProp_file)))
    powers = list(map(int, csv_input[0][1:]))
    visibilities = list(map(float, csv_input[5][1:]))

    powers, visibilities = zip(*sorted(zip(powers, visibilities)))
    return powers, visibilities


file_path = 'results/Final_Set1/final_data_L_CO_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set1_11_12/final_data_L_CO_4PAM/final_data.csv'
powers_11_12, visibilities1_11_12 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_L_CO_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
file_path = 'results/Final_Set2_11_12/final_data_L_CO_4PAM/final_data.csv'
powers_11_12, visibilities2_11_12 = read_csv_data(file_path)

visibilities = list(zip(visibilities1, visibilities2))
visibilities_11_12 = list(zip(visibilities1_11_12, visibilities2_11_12))
visibilities.extend(visibilities_11_12)
powers = list(powers)
powers.extend(powers_11_12)
# print("visibilities:", visibilities)
# print("powers:", powers)



mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-x', label = "L-Band, FS")


file_path = 'results/Final_Set1/final_data_L_COUNTER_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set1_11_12/final_data_L_COUNTER_4PAM/final_data.csv'
powers_11_12, visibilities1_11_12 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_L_COUNTER_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
file_path = 'results/Final_Set2_11_12/final_data_L_COUNTER_4PAM/final_data.csv'
powers_11_12, visibilities2_11_12 = read_csv_data(file_path)

visibilities = list(zip(visibilities1, visibilities2))
visibilities_11_12 = list(zip(visibilities1_11_12, visibilities2_11_12))
visibilities.extend(visibilities_11_12)
powers = list(powers)
powers.extend(powers_11_12)

mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'b-o', label = "L-Band, BS")


file_path = 'results/Final_Set1/final_data_O_CO_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set1_11_12/final_data_O_CO_4PAM/final_data.csv'
powers_11_12, visibilities1_11_12 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_O_CO_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
file_path = 'results/Final_Set2_11_12/final_data_O_CO_4PAM/final_data.csv'
powers_11_12, visibilities2_11_12 = read_csv_data(file_path)

visibilities = list(zip(visibilities1, visibilities2))
visibilities_11_12 = list(zip(visibilities1_11_12, visibilities2_11_12))
visibilities.extend(visibilities_11_12)
powers = list(powers)
powers.extend(powers_11_12)

mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-x', label = "O-Band, FS")


file_path = 'results/Final_Set1/final_data_O_COUNTER_4PAM/final_data.csv'
powers, visibilities1 = read_csv_data(file_path)
file_path = 'results/Final_Set1_11_12/final_data_O_COUNTER_4PAM/final_data.csv'
powers_11_12, visibilities1_11_12 = read_csv_data(file_path)
file_path = 'results/Final_Set2/final_data_O_COUNTER_4PAM/final_data.csv'
powers, visibilities2 = read_csv_data(file_path)
file_path = 'results/Final_Set2_11_12/final_data_O_COUNTER_4PAM/final_data.csv'
powers_11_12, visibilities2_11_12 = read_csv_data(file_path)

visibilities = list(zip(visibilities1, visibilities2))
visibilities_11_12 = list(zip(visibilities1_11_12, visibilities2_11_12))
visibilities.extend(visibilities_11_12)
powers = list(powers)
powers.extend(powers_11_12)

mean_visibilities = np.mean(visibilities, 1)
std_visibilities = np.std(visibilities, 1)
plt.errorbar(powers, mean_visibilities, std_visibilities, fmt = 'r-o', label = "O-Band, BS")

plt.legend()
plt.ylabel("Visibility")
plt.xlabel("Classical Launch Power (dBm)")
# Out:
# Text(0.5, 0, 'Classical Launch Power (dBm)')

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

def read_csv_data(file_path):
    raman_coProp_file = open(file_path, 'r')
    csv_input = list(zip(*csv.reader(raman_coProp_file)))
    powers = list(map(float, csv_input[0][1:]))
    mpn = list(map(float, csv_input[1][1:]))
    visibilities = list(map(float, csv_input[2][1:]))
    # print("powers:", powers, "mpn:", mpn, "visibilties:", visibilities)
    mpn, powers, visibilities = zip(*sorted(zip(mpn, powers, visibilities)))
    # print("powers:", powers, "mpn:", mpn, "visibilties:", visibilities)
    return list(powers), list(mpn), list(visibilities)
    # return powers, visibilities

file_path = 'results/mean_photon_num1/final_data.csv'
powers, mpn, visibilities = read_csv_data(file_path)
powers = powers[0:5]

mpn01 = mpn[0:5]
visibilities01 = visibilities[0:5]

mpn05 = mpn[5:10]
visibilities05 = visibilities[5:10]

mpn1 = mpn[10:15]
visibilities1 = visibilities[10:15]


# print(powers, mpn01, visibilities01)
# print(powers, mpn05, visibilities05)
# print(powers, mpn1, visibilities1)



file_path = 'results/mean_photon_num2/final_data.csv'
powers_45, mpn_45, visibilities_45 = read_csv_data(file_path)
powers_45 = powers_45[0:2]
print(powers_45)
print(visibilities_45)

mpn45_01 = mpn_45[0:2]
visibilities45_01 = visibilities_45[0:2]

mpn45_05 = mpn_45[2:4]
visibilities45_05 = visibilities_45[2:4]

mpn45_1 = mpn_45[4:6]
visibilities45_1 = visibilities_45[4:6]

print(visibilities45_01)
print(visibilities45_05)
print(visibilities45_1)

print("original:", visibilities1)

visibilities01[3:] = visibilities45_01
visibilities05[3:] = visibilities45_05
visibilities1[3:] = visibilities45_1

print("updated:", visibilities1)



file_path = 'results/mean_photon_num3/final_data.csv'
powers_67, mpn_67, visibilities_67 = read_csv_data(file_path)
powers_67 = powers_67[0:2]
powers.extend(powers_67)
# print(powers_67)
# print(visibilities_67)

mpn67_01 = mpn_67[0:2]
visibilities01.extend(visibilities_67[0:2])

mpn45_05 = mpn_45[2:4]
visibilities05.extend(visibilities_45[2:4])

mpn45_1 = mpn_45[4:6]
visibilities1.extend(visibilities_45[4:6])

# print(visibilities45_01)
# print(visibilities45_05)
# print(visibilities45_1)

# print("original:", visibilities1)

# visibilities01[3:] = visibilities45_01
# visibilities05[3:] = visibilities45_05
# visibilities1[3:] = visibilities45_1

# print("updated:", visibilities1)



# plt.plot(powers, visibilities01, label=f"{mpn01[0]}")
plt.plot(powers, visibilities05, label=f"$\mu$: {mpn05[0]}")
plt.plot(powers, visibilities1, label=f"$\mu$: {mpn1[0]}")
plt.legend()
plt.ylabel("Visibility")
plt.xlabel("Classical Launch Power (dBm)")
plt.show()
# Out:
# [4.0, 5.0]
# [1.0526717495685864, 0.8384255578413344, 0.788271268422512, 0.8104605324455116, 0.8366188918040813, 0.770309592583684]
# [1.0526717495685864, 0.8384255578413344]
# [0.788271268422512, 0.8104605324455116]
# [0.8366188918040813, 0.770309592583684]
# original: [0.8949722429000051, 0.7699746961889875, 0.8276558016309594, 0.8137159841565613, 0.7966077383967021]
# updated: [0.8949722429000051, 0.7699746961889875, 0.8276558016309594, 0.8366188918040813, 0.770309592583684]
